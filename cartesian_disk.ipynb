# %%
from IPython.display import HTML
HTML('''<script>
code_show=false; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
 click <a href="javascript:code_toggle()">here</a> to hide the raw code.''')
# Out:
# <script>
# code_show=false;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#  click <a href="javascript:code_toggle()">here</a> to hide the raw code.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import yt
# %matplotlib inline

# %%
#import athena_read as ath
fdir =  '/tigress/jiming/athena/bin/single/'
targ = ''
fname = fdir+targ+'sd.out1.00040.athdf'
#time,data=ath.hdf5(fname)
ds = yt.load(fname)
# Out:
# yt : [WARNING  ] 2017-09-25 17:13:21,137 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2017-09-25 17:13:21,141 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2017-09-25 17:13:21,144 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2017-09-25 17:13:21,147 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2017-09-25 17:13:21,194 Parameters: current_time              = 251.328740367
# yt : [INFO     ] 2017-09-25 17:13:21,195 Parameters: domain_dimensions         = [512 512   1]
# yt : [INFO     ] 2017-09-25 17:13:21,196 Parameters: domain_left_edge          = [-5.  -5.  -0.4]
# yt : [INFO     ] 2017-09-25 17:13:21,197 Parameters: domain_right_edge         = [ 5.   5.   0.4]
# yt : [INFO     ] 2017-09-25 17:13:21,198 Parameters: cosmological_simulation   = 0.0

# %%
#ds = yt.load(filename)
sphere = ds.sphere(ds.domain_center, (300.0, "kpc"))
print sphere["density"][1:50].value
vr = yt.create_profile(sphere, 'radius', 'density',
                        units = {'radius': 'code_length'},
                        logs = {'radius': False})



#profile = yt.create_profile(sphere, "radius", "density",
#                            weight_field = "cell_volume",
#                            units = {'radius': 'kpc'},
#                            logs={'radius':False})

#plot = yt.ProfilePlot(sphere, "radius", "density",
#                      weight_field="cell_mass")
# Out:
# [ 0.37679651  0.37716538  0.37753457  0.37790412  0.37827402  0.37864423
#   0.37901479  0.37938565  0.37975684  0.38012835  0.38050014  0.38087225
#   0.38124463  0.38161731  0.38199025  0.38236347  0.38273695  0.38311067
#   0.38348466  0.38385892  0.38423339  0.38460806  0.38498297  0.38535812
#   0.38573346  0.38610899  0.38648471  0.38686064  0.38723671  0.38761297
#   0.38798937  0.38836592  0.38874263  0.38911945  0.38949642  0.38987347
#   0.39025065  0.39062792  0.39100528  0.39138272  0.39176023  0.3921378
#   0.39251539  0.39289305  0.39327073  0.39364845  0.39402616  0.39440387
#   0.39478156]

# %%
plot.show()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
print sphere.
# Out:
# 9.25703274289e+23 code_length
